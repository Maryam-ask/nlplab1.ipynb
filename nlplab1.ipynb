# %% [markdown]
# ## This is laboration exercise 1 Basic NLP processing in the Natural Language Processing - NLP course by Hercules Dalianis

# %% [markdown]
# Download the BBB Politics and Business corpus
# http://people.dsv.su.se/hercules/BBC_politics_business.txt
# and put in a folder called NLP-lab1

# %%
# Start Jupiter notebook or your Python interpreted and open the 
# Corpus file
corpusFilePointer = open("BBC_politics_business.txt")

# %%
corpusText = corpusFilePointer.read()
corpusFilePointer.close()

# %%
# Import NLTK library
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Tokenize the Corpus using the nltk.word_tokenize()
word_t = nltk.word_tokenize(corpusText)

# %%
# 1)
# Calculate the number of tokens in the corpus. 
# Think about it as length of a list.
print("Number of tokens: ", len(word_t))
# Out:
# Number of tokens:  84337

# %%
# 2)
# Calculate the number of unique tokens (types) there are in the corpus. 
# "This is a token. This is another token." There are two occurancies of "token" in the previous
# string but one type "token".
# To calculate the types think about the set() function
types = set(word_t)
print("Number of unique tokens(types): ", len(types))
# Out:
# Number of unique tokens(types):  9763

# %%
# Import the predefined stopwords in NLTK
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# 3)
# How many stopword are there in the stop word list? 
# Are this few or many stop words, can you think about 
# other stopwords?
print("# of Stopwords: ", len(stop_words))
# Out:
# # of Stopwords:  179
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Write a Python function that filters out the stopwords from 
# the BBC corpus
def stopWords_filter(words):
    filtered_words = []
    for w in words:
        if w not in stop_words:
            filtered_words.append(w)
    return filtered_words     # to avoid similar words

# %%
# 4) 
# How many tokens are there in the BBC corpus after filter out the stopwords
# are these reasonable or to many or too few?
filtered_words = stopWords_filter(word_t)
print("# Tokens after filter out the stopwords: ", len(filtered_words))
# Out:
# # Tokens after filer out the stopwords:  56299

# %%
# Check if all stopwords really were removed from the BBC corpus
# Can you write a Python function that also matches initial uppercase stopwords
"""def stopWords_filter2(words):
    initial_upper_stop_words = []
    for stop_w in stop_words:
        if stop_w.capitalize() in words:    # .capitalize() for initial uppercase
            initial_upper_stop_words.append(stop_w)
    return initial_upper_stop_words     # to avoid similar words  

filtered_words2 = stopWords_filter2(filtered_words)

print(len(filtered_words2))"""
def stopWords_filter2(words):
    filtered_words = []
    capatilized_stopwords = []
    for w in stop_words:
        capatilized_stopwords.append(w.capitalize())
    # print(capatilized_stopwords)
    for w in words:
        if w not in capatilized_stopwords:
            filtered_words.append(w)
    return filtered_words
filtered_words2 = stopWords_filter2(filtered_words)
print("Number of filtered words:", len(filtered_words2))
# Out:
# Number of filtered words: 54009

# %%
# 5)
# How many tokens are there in the BBC corpus after filtering also
# in lower case?
def stopWords_filter3(words):
    filtered_words = []
    for w in words:
        if w.lower() not in stop_words:
            filtered_words.append(w)
    return filtered_words     # to avoid similar words  

filtered_words3 = stopWords_filter3(filtered_words)
print(len(filtered_words3))
# Out:
# 54006

# %%
# 6)
# How many types do you have now?

filtered_types = set(filtered_words3)
print("# types after filter: ", len(filtered_types))
# Out:
# # types after filter:  9565

# %%
# Import the WordNet lemmatizer in NLTK
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Write a Python function that lemmatizes the tokens in the BBC corpus
def lemmatize_func(tokens):
    lemmas = []
    for t in tokens:
        lemma = lemmatizer.lemmatize(t)
        lemmas.append(lemma)
    return lemmas

# %%
# 7)
# How many types do you have in the BBC corpus after lemmatization?

lemmatize_types = set(lemmatize_func(filtered_words3))
print("types after lema:", len(lemmatize_types))
# Out:
# types after lema: 8815

# %%
#from nltk.stem import PorterStemmer
#stemmer =  PorterStemmer()

stemmer = nltk.stem.PorterStemmer()

# %%
# Write a Python function that stems the tokens in the BBC corpus
def stem_token(stopfilteredCorpus):
    stemmedCorpus = []
    for w in stopfilteredCorpus:
        stemmedCorpus.append(stemmer.stem(w))
    return stemmedCorpus

# %%
# 8)
# How many types do you have in the BBC Corpus after stemming?
# Are there any differences? If so, why?
stemmedCorpus = stem_token(filtered_words3)
len(stemmedCorpus)
len(set(stemmedCorpus))
# Out:
# 6506

# %% [markdown]
# ### Now we are ready with the corpus linguistic part of the laboration exercise and we start with POS taggning and Chunking which is more NLP processing tasks.

# %%
# Use the nltk.pos_tag() function to POS tag the BBC corpus
nltk.download('averaged_perceptron_tagger')
tagged_text = nltk.pos_tag(word_t)
tagged_text
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Prime', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Tony', 'NNP'),
#  ('Blair', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('announce', 'VB'),
#  ('new', 'JJ'),
#  ('measures', 'NNS'),
#  ('to', 'TO'),
#  ('strengthen', 'VB'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('Asbos', 'NNP'),
#  ('and', 'CC'),
#  ('fixed', 'VBD'),
#  ('penalty', 'NN'),
#  ('notices', 'NNS'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('still', 'RB'),
#  ('concerns', 'NNS'),
#  ('that', 'IN'),
#  ('some', 'DT'),
#  ('areas', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('powers', 'NNS'),
#  ('properly', 'RB'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('say', 'VB'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('figures', 'NNS'),
#  ('were', 'VBD'),
#  ('heartening', 'VBG'),
#  ('but', 'CC'),
#  ('he', 'PRP'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('rest', 'VB'),
#  ('until', 'IN'),
#  ('similar', 'JJ'),
#  ('action', 'NN'),
#  ('was', 'VBD'),
#  ('taken', 'VBN'),
#  ('in', 'IN'),
#  ('all', 'DT'),
#  ('areas', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('where', 'WRB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('needed', 'VBN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('not', 'RB'),
#  ('defeated', 'VBN'),
#  ('this', 'DT'),
#  ('problem', 'NN'),
#  ('by', 'IN'),
#  ('any', 'DT'),
#  ('means', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('shown', 'VBN'),
#  ('together', 'RB'),
#  ('what', 'WP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('done', 'VBN'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('will', 'MD'),
#  ('say', 'VB'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('Blair', 'NNP'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('defended', 'VBD'),
#  ('the', 'DT'),
#  ('shake-up', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('licensing', 'NN'),
#  ('laws', 'NNS'),
#  (',', ','),
#  ('saying', 'VBG'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('right', 'JJ'),
#  ('to', 'TO'),
#  ('focus', 'VB'),
#  ('on', 'IN'),
#  ('troublemakers', 'NNS'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('treating', 'VBG'),
#  ('everybody', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('potential', 'JJ'),
#  ('drunken', 'NN'),
#  ('nuisance', 'NN'),
#  ('.', '.'),
#  ('Ministers', 'NNS'),
#  ('also', 'RB'),
#  ('boast', 'IN'),
#  ('of', 'IN'),
#  ('record', 'NN'),
#  ('police', 'NN'),
#  ('numbers', 'NNS'),
#  ('and', 'CC'),
#  ('are', 'VBP'),
#  ('speeding', 'VBG'),
#  ('up', 'RP'),
#  ('plans', 'NNS'),
#  ('to', 'TO'),
#  ('put', 'VB'),
#  ('in', 'IN'),
#  ('place', 'NN'),
#  ('25,000', 'CD'),
#  ('community', 'NN'),
#  ('support', 'NN'),
#  ('officers', 'NNS'),
#  ('(', '('),
#  ('CSOs', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('researchers', 'NNS'),
#  ('from', 'IN'),
#  ('Leeds', 'NNP'),
#  ('University', 'NNP'),
#  ('warned', 'VBD'),
#  ('that', 'IN'),
#  ('CSOs', 'NNP'),
#  ('could', 'MD'),
#  ('undermine', 'VB'),
#  ('traditional', 'JJ'),
#  ('bonds', 'NNS'),
#  ('between', 'IN'),
#  ('police', 'NN'),
#  ('officers', 'NNS'),
#  ('and', 'CC'),
#  ('communities', 'NNS'),
#  ('.', '.'),
#  ('More', 'JJR'),
#  ('work', 'NN'),
#  ('needed', 'VBN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('done', 'VBN'),
#  ('on', 'IN'),
#  ('clarifying', 'VBG'),
#  ('the', 'DT'),
#  ('role', 'NN'),
#  ('of', 'IN'),
#  ('different', 'JJ'),
#  ('agencies', 'NNS'),
#  ('and', 'CC'),
#  ('how', 'WRB'),
#  ('they', 'PRP'),
#  ('linked', 'VBD'),
#  ('together', 'RB'),
#  ('before', 'IN'),
#  ('CSOs', 'NNP'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('argued', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('the', 'DT'),
#  ('study', 'NN'),
#  ('.', '.'),
#  ('Critics', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('say', 'VBP'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('announced', 'VBN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('20', 'CD'),
#  ('initiatives', 'NNS'),
#  ('to', 'TO'),
#  ('tackle', 'VB'),
#  ('nuisance', 'RB'),
#  ('behaviour', 'NN'),
#  ('when', 'WRB'),
#  ('the', 'DT'),
#  ('real', 'JJ'),
#  ('focus', 'NN'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('on', 'IN'),
#  ('good', 'JJ'),
#  ('policing', 'NN'),
#  ('.', '.'),
#  ('Home', 'NNP'),
#  ('Office', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Hazel', 'NNP'),
#  ('Blears', 'NNP'),
#  ('also', 'RB'),
#  ('revealed', 'VBD'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('that', 'IN'),
#  ('``', '``'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('third', 'JJ'),
#  ("''", "''"),
#  ('of', 'IN'),
#  ('Asbos', 'NNP'),
#  ('were', 'VBD'),
#  ('breached', 'VBN'),
#  ('-', ':'),
#  ('with', 'IN'),
#  ('some', 'DT'),
#  ('people', 'NNS'),
#  ('jailed', 'VBN'),
#  ('and', 'CC'),
#  ('others', 'NNS'),
#  ('not', 'RB'),
#  ('.', '.'),
#  ('Kennedy', 'NNP'),
#  ('calls', 'VBZ'),
#  ('for', 'IN'),
#  ('Iraq', 'NNP'),
#  ('exit', 'NN'),
#  ('plans', 'NNS'),
#  ('Tony', 'NNP'),
#  ('Blair', 'NNP'),
#  ('should', 'MD'),
#  ('set', 'VB'),
#  ('out', 'RP'),
#  ('a', 'DT'),
#  ('proper', 'JJ'),
#  ('exit', 'NN'),
#  ('strategy', 'NN'),
#  ('from', 'IN'),
#  ('Iraq', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wake', 'NN'),
#  ('of', 'IN'),
#  ('next', 'JJ'),
#  ('Sunday', 'NNP'),
#  ("'s", 'POS'),
#  ('elections', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  (',', ','),
#  ('Lib', 'NNP'),
#  ('Dem', 'NNP'),
#  ('leader', 'NN'),
#  ('Charles', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('a', 'DT'),
#  ('speech', 'NN'),
#  ('focusing', 'VBG'),
#  ('on', 'IN'),
#  ('issues', 'NNS'),
#  ('arising', 'VBG'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('re-election', 'NN'),
#  ('of', 'IN'),
#  ('George', 'NNP'),
#  ('W', 'NNP'),
#  ('Bush', 'NNP'),
#  (',', ','),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('said', 'VBD'),
#  ('Iraq', 'NNP'),
#  ('had', 'VBD'),
#  ('become', 'VBN'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('crucible', 'JJ'),
#  ('of', 'IN'),
#  ('militant', 'JJ'),
#  ('terrorism', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('wants', 'VBZ'),
#  ('to', 'TO'),
#  ('see', 'VB'),
#  ('a', 'DT'),
#  ('phased', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('of', 'IN'),
#  ('UK', 'NNP'),
#  ('troops', 'VBZ'),
#  ('``', '``'),
#  ('as', 'RB'),
#  ('soon', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('situation', 'NN'),
#  ('allows', 'VBZ'),
#  ("''", "''"),
#  (',', ','),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('London', 'NNP'),
#  ('.', '.'),
#  ('Any', 'NNP'),
#  ('exit', 'NN'),
#  ('strategy', 'NN'),
#  ('must', 'MD'),
#  ('``', '``'),
#  ('augment', 'NN'),
#  ('and', 'CC'),
#  ('support', 'NN'),
#  ("''", "''"),
#  ('the', 'DT'),
#  ('democratic', 'JJ'),
#  ('process', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('some', 'DT'),
#  ('who', 'WP'),
#  ('are', 'VBP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('opinion', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('mere', 'JJ'),
#  ('presence', 'NN'),
#  ('of', 'IN'),
#  ('British', 'JJ'),
#  ('and', 'CC'),
#  ('American', 'JJ'),
#  ('troops', 'NNS'),
#  ('in', 'IN'),
#  ('Iraq', 'NNP'),
#  ('feeds', 'VBZ'),
#  ('the', 'DT'),
#  ('insurgency', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('some', 'DT'),
#  ('truth', 'NN'),
#  ('in', 'IN'),
#  ('that', 'DT'),
#  (',', ','),
#  ('especially', 'RB'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('initial', 'JJ'),
#  ('mistakes', 'NNS'),
#  ('that', 'WDT'),
#  ('were', 'VBD'),
#  ('made', 'VBN'),
#  ('-', ':'),
#  ('the', 'DT'),
#  ('heavy-handedness', 'NN'),
#  ('of', 'IN'),
#  ('operations', 'NNS'),
#  ('like', 'IN'),
#  ('Fallujah', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('well-publicised', 'JJ'),
#  ('instances', 'NNS'),
#  ('of', 'IN'),
#  ('abuse', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('hands', 'NNS'),
#  ('of', 'IN'),
#  ('coalition', 'NN'),
#  ('forces', 'NNS'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('pointed', 'VBD'),
#  ('out', 'RP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('Netherlands', 'NNP'),
#  (',', ','),
#  ('Portugal', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('all', 'DT'),
#  ('have', 'VBP'),
#  ('troops', 'NNS'),
#  ('operating', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('southern', 'JJ'),
#  ('sector', 'NN'),
#  ('of', 'IN'),
#  ('Iraq', 'NNP'),
#  (',', ','),
#  ('have', 'VBP'),
#  ('announced', 'VBN'),
#  ('their', 'PRP$'),
#  ('imminent', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('``', '``'),
#  ('regardless', 'RB'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('situation', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('ground', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('accused', 'VBD'),
#  ('Mr', 'NNP'),
#  ('Blair', 'NNP'),
#  ("'s", 'POS'),
#  ('government', 'NN'),
#  ('of', 'IN'),
#  ('``', '``'),
#  ('being', 'VBG'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('straightforward', 'NN'),
#  ("''", "''"),
#  ('over', 'IN'),
#  ('its', 'PRP$'),
#  ('plans', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Next', 'JJ'),
#  ('week', 'NN'),
#  ('the', 'DT'),
#  ('prime', 'JJ'),
#  ('minister', 'NN'),
#  ('should', 'MD'),
#  ('make', 'VB'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('regarding', 'VBG'),
#  ('the', 'DT'),
#  ('elections', 'NNS'),
#  ('in', 'IN'),
#  ('Iraq', 'NNP'),
#  (',', ','),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('said', 'VBD'),
#  ('during', 'IN'),
#  ('his', 'PRP$'),
#  ('City', 'NNP'),
#  ('of', 'IN'),
#  ('London', 'NNP'),
#  ('speech', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('He', 'PRP'),
#  ('should', 'MD'),
#  ('set', 'VB'),
#  ('out', 'RP'),
#  ('a', 'DT'),
#  ('proper', 'JJ'),
#  ('exit', 'NN'),
#  ('strategy', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('the', 'DT'),
#  ('phased', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('of', 'IN'),
#  ('British', 'JJ'),
#  ('troops', 'NNS'),
#  (',', ','),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('security', 'NN'),
#  ('situation', 'NN'),
#  ('allows', 'VBZ'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('also', 'RB'),
#  ('argued', 'VBD'),
#  ('that', 'IN'),
#  ('British', 'JJ'),
#  ('troops', 'NNS'),
#  ('deployed', 'VBN'),
#  ('in', 'IN'),
#  ('Iraq', 'NNP'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('replaced', 'VBN'),
#  ('with', 'IN'),
#  ('forces', 'NNS'),
#  ('from', 'IN'),
#  ('other', 'JJ'),
#  ('countries', 'NNS'),
#  ('-', ':'),
#  ('``', '``'),
#  ('especially', 'RB'),
#  ('Islamic', 'JJ'),
#  ('countries', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('McConnell', 'NNP'),
#  ('in', 'IN'),
#  ("'drunk", 'NNP'),
#  ("'", 'POS'),
#  ('remark', 'NN'),
#  ('row', 'NN'),
#  ('Scotland', 'NNP'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('minister', 'NN'),
#  ('has', 'VBZ'),
#  ('told', 'VBN'),
#  ('a', 'DT'),
#  ('group', 'NN'),
#  ('of', 'IN'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('pupils', 'NNS'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('okay', 'VBN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('drunk', 'JJ'),
#  ('``', '``'),
#  ('once', 'RB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('while', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Jack', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('to', 'TO'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('100', 'CD'),
#  ('secondary', 'JJ'),
#  ('pupils', 'NNS'),
#  ('from', 'IN'),
#  ('schools', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Highlands', 'NNS'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('problems', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('drink', 'NN'),
#  ('promotions', 'NNS'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('criticised', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('SNP', 'NNP'),
#  ('for', 'IN'),
#  ('encouraging', 'VBG'),
#  ('young', 'JJ'),
#  ('people', 'NNS'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('drunk', 'JJ'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('the', 'DT'),
#  ('Scottish', 'NNP'),
#  ('Executive', 'NNP'),
#  ('has', 'VBZ'),
#  ('insisted', 'VBN'),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('about', 'IN'),
#  ('adults', 'NNS'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('comments', 'NNS'),
#  ('were', 'VBD'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('recognition', 'NN'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('drunk', 'JJ'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('first', 'JJ'),
#  ('minister', 'NN'),
#  ("'s", 'POS'),
#  ('comments', 'NNS'),
#  ('came', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('question', 'NN'),
#  ('and', 'CC'),
#  ('answer', 'NN'),
#  ('session', 'NN'),
#  ('at', 'IN'),
#  ('Glenurquhart', 'NNP'),
#  ('High', 'NNP'),
#  ('School', 'NNP'),
#  ('in', 'IN'),
#  ('Inverness', 'NNP'),
#  (',', ','),
#  ('attended', 'VBN'),
#  ('by', 'IN'),
#  ('pupils', 'NNS'),
#  ('from', 'IN'),
#  ('a', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('secondary', 'JJ'),
#  ('schools', 'NNS'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('Highland', 'NNP'),
#  ('councillor', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('event', 'NN'),
#  ('has', 'VBZ'),
#  ('also', 'RB'),
#  ('defended', 'VBN'),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('.', '.'),
#  ('Margaret', 'NNP'),
#  ('Davidson', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('independent', 'JJ'),
#  ('member', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('Loch', 'NNP'),
#  ('Ness', 'NNP'),
#  ('West', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('minister', 'NN'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('general', 'JJ'),
#  ('way', 'NN'),
#  ('and', 'CC'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('sure', 'RB'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('about', 'IN'),
#  ('adults', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('one', 'CD'),
#  ('pupil', 'NN'),
#  ('asked', 'VBD'),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('how', 'WRB'),
#  ('the', 'DT'),
#  ('executive', 'NN'),
#  ('proposed', 'VBD'),
#  ('to', 'TO'),
#  ('tackle', 'VB'),
#  ('under-age', 'JJ'),
#  ('drinking', 'NN'),
#  (',', ','),
#  ('began', 'VBD'),
#  ('his', 'PRP$'),
#  ('response', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('quip', 'NN'),
#  (':', ':'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('sure', 'JJ'),
#  ('there', 'EX'),
#  ("'s", 'VBZ'),
#  ('no', 'DT'),
#  ('under-age', 'JJ'),
#  ('drinking', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Highlands', 'NNP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('He', 'PRP'),
#  ('went', 'VBD'),
#  ('on', 'IN'),
#  ('to', 'TO'),
#  ('speak', 'VB'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('evils', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('railed', 'VBN'),
#  ('against', 'IN'),
#  ('irresponsible', 'JJ'),
#  ('drinks', 'NNS'),
#  ('promotions', 'NNS'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  (':', ':'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('hope', 'VBP'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('not', 'RB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('seen', 'VBN'),
#  ('as', 'IN'),
#  ('preaching', 'VBG'),
#  ('to', 'TO'),
#  ('anybody', 'NN'),
#  ('here', 'RB'),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('really', 'RB'),
#  ('serious', 'JJ'),
#  ('problem', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('moment', 'NN'),
#  ('is', 'VBZ'),
#  ('binge', 'JJ'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('impact', 'NN'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('on', 'IN'),
#  ('people', 'NNS'),
#  ("'s", 'POS'),
#  ('health', 'NN'),
#  ('and', 'CC'),
#  ('their', 'PRP$'),
#  ('ability', 'NN'),
#  ('to', 'TO'),
#  ('control', 'VB'),
#  ('what', 'WP'),
#  ("'s", 'VBZ'),
#  ('happening', 'VBG'),
#  ('round', 'NN'),
#  ('about', 'IN'),
#  ('them', 'PRP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('regularly', 'RB'),
#  ('saw', 'VBD'),
#  ('reports', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('effects', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('sprees', 'NNS'),
#  ('which', 'WDT'),
#  ('ended', 'VBD'),
#  ('in', 'IN'),
#  ('assaults', 'NNS'),
#  ('or', 'CC'),
#  ('even', 'RB'),
#  ('rapes', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('health', 'NN'),
#  ('consequences', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('one', 'CD'),
#  ('thing', 'NN'),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('something', 'NN'),
#  ('really', 'RB'),
#  ('serious', 'JJ'),
#  ('about', 'IN'),
#  ('is', 'VBZ'),
#  ('binge', 'JJ'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('irresponsible', 'JJ'),
#  ('drinks', 'NNS'),
#  ('promotions', 'NNS'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('help', 'VB'),
#  ('lead', 'VB'),
#  ('to', 'TO'),
#  ('that', 'DT'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Far', 'NNP'),
#  ('too', 'RB'),
#  ('many', 'JJ'),
#  ('pub', 'NN'),
#  ('chains', 'NNS'),
#  ('in', 'IN'),
#  ('particular', 'JJ'),
#  ('are', 'VBP'),
#  ('selling', 'VBG'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('much', 'JJ'),
#  ('booze', 'NN'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('cheaply', 'JJ'),
#  ('and', 'CC'),
#  ('encouraging', 'JJ'),
#  ('people', 'NNS'),
#  ('to', 'TO'),
#  ('drink', 'VB'),
#  ('it', 'PRP'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('quickly', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('are', 'VBP'),
#  ('go', 'VB'),
#  ('to', 'TO'),
#  ('clamp', 'VB'),
#  ('down', 'RP'),
#  ('on', 'IN'),
#  ('that', 'DT'),
#  ('and', 'CC'),
#  ('make', 'VB'),
#  ('those', 'DT'),
#  ('promotions', 'NNS'),
#  ('illegal', 'VBP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('hope', 'NN'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('can', 'MD'),
#  ('enjoy', 'VB'),
#  ('a', 'DT'),
#  ('drink', 'NN'),
#  ('sensibly', 'RB'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('course', 'NN'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('evening', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('He', 'PRP'),
#  ('added', 'VBD'),
#  (':', ':'),
#  ('``', '``'),
#  ('By', 'IN'),
#  ('all', 'DT'),
#  ('means', 'NNS'),
#  ('get', 'VBP'),
#  ('drunk', 'JJ'),
#  ('once', 'RB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('while', 'NN'),
#  ('-', ':'),
#  ('but', 'CC'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('get', 'VB'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('situation', 'NN'),
#  ('where', 'WRB'),
#  ('people', 'NNS'),
#  ('are', 'VBP'),
#  ('being', 'VBG'),
#  ('encouraged', 'VBN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('completely', 'RB'),
#  ('incapable', 'JJ'),
#  ('just', 'RB'),
#  ('to', 'TO'),
#  ('save', 'VB'),
#  ('some', 'DT'),
#  ('money', 'NN'),
#  ('and', 'CC'),
#  ('drink', 'VB'),
#  ('more', 'JJR'),
#  ('quickly', 'RB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('SNP', 'NNP'),
#  ('Holyrood', 'NNP'),
#  ('leader', 'NN'),
#  ...]

# %% [markdown]
# 9)
# Inspect the tagged corpus, what types of tags do you see?
# What do they mean?

# %% [markdown]
# Here follows an example with a short sentence to introduce chunking

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')

sent = ("Israeli Prime Minister Ehud Olmert is scheduled to meet with Palestinian President Mahmoud Abbas Wednesday in Jerusalem. Palestinian negotiator Saeb Erekat said the talks will focus on permanent- status issues, Israeli checkpoints and the fate of Palestinian prisoners. The meeting, at Mr. Olmert's official residence, will be the first between the two since Mr. Olmert announced that he will step down after his Kadima Party chooses a new leader in September. The two leaders re-started peace talks in November with the goal of reaching a deal by this year's end")

# Tokenisation
tokenised = nltk.word_tokenize(sent)

# Taggning
tagged = nltk.pos_tag(tokenised)

# Chunking
sentChunked = nltk.ne_chunk(tagged)

#PERSON, ORGANIZATION and GPE

#Print some named entities in the sentence
for n in sentChunked:
    if isinstance(n, nltk.tree.Tree):               
        if n.label() == 'PERSON' or n.label() == 'ORGANIZATION' or n.label() == 'GPE':
            print(n)
        else:
            n
            print(n)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (GPE Israeli/JJ)
# (PERSON Ehud/NNP Olmert/NNP)
# (GPE Palestinian/NNP)
# (PERSON Mahmoud/NNP Abbas/NNP)
# (GPE Jerusalem/NNP)
# (GPE Palestinian/JJ)
# (PERSON Saeb/NNP Erekat/NNP)
# (GPE Israeli/JJ)
# (GPE Palestinian/JJ)
# (PERSON Mr./NNP Olmert/NNP)
# (PERSON Mr./NNP Olmert/NNP)
# (ORGANIZATION Kadima/NNP Party/NNP)

# %% [markdown]
# Use the function draw() to draw a chunktree (shallow parse tree),

# %%
sentChunked.draw()

# %% [markdown]
# 10)
# Count the number of Persons, Organisation and GPEs, Geo Political Entities in the BBC corpus. Follow the above example and extend the function.

# %% [markdown]
# The chunking of the BBC corpus takes some time, please be patient.

# %%
print('Chunking')
# Out:
# Chunking

# %%
# Chunking
chunking_text = nltk.ne_chunk(tagged_text)
person_list=[]
organization_list= []
gpe_list= []
for w in chunking_text:
    if isinstance(w, nltk.tree.Tree):               
        if w.label() == 'PERSON':
            person_list.append(w)
        elif w.label() == 'ORGANIZATION':
            organization_list.append(w)
        elif w.label() == 'GPE':
            gpe_list.append(w)
        else:
            w

# %%
# Number of PERSON
print("Number of PERSON:", len(person_list))
# Out:
# Number of PERSON: 1886

# %%
# Number of ORGANIZATION
print("Number of ORGANIZATION: ", len(organization_list))
# Out:
# Number of ORGANIZATION:  1543

# %%
# Number of GPE/locations
print("Number of GPE/locations: ", len(gpe_list))
# Out:
# Number of GPE/locations:  1432

# %% [markdown]
# ### Now we will study N-grams
# See example below, fill in the missing code.
#
# 11) Are there any bigrams or trigram or ngrams that give
# logical groups of texts/grams?

# %%
import nltk
from nltk import bigrams,trigrams
sent = ("Israeli Prime Minister Ehud Olmert is scheduled to meet with Palestinian President Mahmoud Abbas Wednesday in Jerusalem. Palestinian negotiator Saeb Erekat said the talks will focus on permanent- status issues, Israeli checkpoints and the fate of Palestinian prisoners. The meeting, at Mr. Olmert's official residence, will be the first between the two since Mr. Olmert announced that he will step down after his Kadima Party chooses a new leader in September. The two leaders re-started peace talks in November with the goal of reaching a deal by this year's end")
tokenised = nltk.word_tokenize(sent)
grams = trigrams(tokenised)
for gram in grams:
  print(gram)
# Out:
# ('Israeli', 'Prime', 'Minister')
# ('Prime', 'Minister', 'Ehud')
# ('Minister', 'Ehud', 'Olmert')
# ('Ehud', 'Olmert', 'is')
# ('Olmert', 'is', 'scheduled')
# ('is', 'scheduled', 'to')
# ('scheduled', 'to', 'meet')
# ('to', 'meet', 'with')
# ('meet', 'with', 'Palestinian')
# ('with', 'Palestinian', 'President')
# ('Palestinian', 'President', 'Mahmoud')
# ('President', 'Mahmoud', 'Abbas')
# ('Mahmoud', 'Abbas', 'Wednesday')
# ('Abbas', 'Wednesday', 'in')
# ('Wednesday', 'in', 'Jerusalem')
# ('in', 'Jerusalem', '.')
# ('Jerusalem', '.', 'Palestinian')
# ('.', 'Palestinian', 'negotiator')
# ('Palestinian', 'negotiator', 'Saeb')
# ('negotiator', 'Saeb', 'Erekat')
# ('Saeb', 'Erekat', 'said')
# ('Erekat', 'said', 'the')
# ('said', 'the', 'talks')
# ('the', 'talks', 'will')
# ('talks', 'will', 'focus')
# ('will', 'focus', 'on')
# ('focus', 'on', 'permanent-')
# ('on', 'permanent-', 'status')
# ('permanent-', 'status', 'issues')
# ('status', 'issues', ',')
# ('issues', ',', 'Israeli')
# (',', 'Israeli', 'checkpoints')
# ('Israeli', 'checkpoints', 'and')
# ('checkpoints', 'and', 'the')
# ('and', 'the', 'fate')
# ('the', 'fate', 'of')
# ('fate', 'of', 'Palestinian')
# ('of', 'Palestinian', 'prisoners')
# ('Palestinian', 'prisoners', '.')
# ('prisoners', '.', 'The')
# ('.', 'The', 'meeting')
# ('The', 'meeting', ',')
# ('meeting', ',', 'at')
# (',', 'at', 'Mr.')
# ('at', 'Mr.', 'Olmert')
# ('Mr.', 'Olmert', "'s")
# ('Olmert', "'s", 'official')
# ("'s", 'official', 'residence')
# ('official', 'residence', ',')
# ('residence', ',', 'will')
# (',', 'will', 'be')
# ('will', 'be', 'the')
# ('be', 'the', 'first')
# ('the', 'first', 'between')
# ('first', 'between', 'the')
# ('between', 'the', 'two')
# ('the', 'two', 'since')
# ('two', 'since', 'Mr.')
# ('since', 'Mr.', 'Olmert')
# ('Mr.', 'Olmert', 'announced')
# ('Olmert', 'announced', 'that')
# ('announced', 'that', 'he')
# ('that', 'he', 'will')
# ('he', 'will', 'step')
# ('will', 'step', 'down')
# ('step', 'down', 'after')
# ('down', 'after', 'his')
# ('after', 'his', 'Kadima')
# ('his', 'Kadima', 'Party')
# ('Kadima', 'Party', 'chooses')
# ('Party', 'chooses', 'a')
# ('chooses', 'a', 'new')
# ('a', 'new', 'leader')
# ('new', 'leader', 'in')
# ('leader', 'in', 'September')
# ('in', 'September', '.')
# ('September', '.', 'The')
# ('.', 'The', 'two')
# ('The', 'two', 'leaders')
# ('two', 'leaders', 're-started')
# ('leaders', 're-started', 'peace')
# ('re-started', 'peace', 'talks')
# ('peace', 'talks', 'in')
# ('talks', 'in', 'November')
# ('in', 'November', 'with')
# ('November', 'with', 'the')
# ('with', 'the', 'goal')
# ('the', 'goal', 'of')
# ('goal', 'of', 'reaching')
# ('of', 'reaching', 'a')
# ('reaching', 'a', 'deal')
# ('a', 'deal', 'by')
# ('deal', 'by', 'this')
# ('by', 'this', 'year')
# ('this', 'year', "'s")
# ('year', "'s", 'end')

# %% [markdown]
# ### Now we will do some regular expression matching

# %%
# Import regular expression library for Python
import re

# Match all Sweden in the corpusText
re.findall(r"Sweden", corpusText)
# Out:
# ['Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden']

# %% [markdown]
# Do the same for Sweden again but extract also the snippet/text around them.
#
# 12) What do you see?

# %%
re.findall(".{0,20}Sweden.{0,20}", corpusText) # 20 characters befor and after Sweden
# Out:
# ['the UK third behind Sweden and Ireland for bus',
#  'ly, Switzerland and Sweden will be stored perm',
#  'l sides of Ireland, Sweden and Norway. Shares ',
#  'end up producing in Sweden?"',
#  ' build Cadillacs in Sweden',
#  'ing Saab factory in Sweden.',
#  'lloyed good news in Sweden, since it reflects ',
#  ' American marque in Sweden is part of its effo',
#  'illac production to Sweden should help introdu']

# %% [markdown]
# Do the same for the car company SAAB but extract also the snippet/text around them.
#
# 13) What do you see?

# %%
re.findall(".{0,20}Saab.{0,20}", corpusText)
# Out:
# ['pean units Opel and Saab have both had troub',
#  'Saab to build Cadillacs ',
#  ' at its loss-making Saab factory in Sweden.',
#  " allay fears of the Saab factory's closure. ",
#  ", since it reflects Saab's failure to make s",
#  ' market. For years, Saab has consistently sa',
#  'needed scale to the Saab factory, which curr',
#  'ble operations, and Saab is losing money fas',
#  'nditure by building Saabs, Opels - badged as',
#  "y to further reduce Saab's losses could be t",
#  'f the production of Saabs to the US, a marke',
#  'ar, which is making Saabs more expensive to ']

# %% [markdown]
# Combine the two regular expressions so get both Sweden and Saab in the same context.
#
# 14) Are the results comprehensible? How can you improve them?

# %%
print(re.findall(".{0,20}Sweden.{0,20}" + ".{0,20}Saab.{0,20}",corpusText))
# Out:
# ["lloyed good news in Sweden, since it reflects Saab's failure to make s"]

# %% [markdown]
# ### Here is an extra task which is not compulsary.
# Match all organisations that is close to Sweden in the BBC corpus and print the snippets.
#
# 15) What do you get? Are there repetitions? How can one avoid them?

# %%
close_sweden = "".join(re.findall(".{0,60}Sweden.{0,60}", corpusText))
#print(close_sweden)
close_sweden_tokens = nltk.word_tokenize(close_sweden)
close_sweden_tags = nltk.pos_tag(close_sweden_tokens)
close_sweden_chunks = nltk.ne_chunk(close_sweden_tags)
for w in close_sweden_chunks:
    if isinstance(w, nltk.tree.Tree): 
        if w.label() == 'ORGANIZATION':
            print(set(w))
# Out:
# {('HI', 'NNP'), ('Europe', 'NNP')}
# {('UK', 'NNP')}
# {('UK', 'NNP')}
# {('inroaGM', 'NN')}
# {('Saab', 'NNP')}
